# %%
pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# accelerate                        1.9.0
# aiobotocore                       2.19.0
# aiohappyeyeballs                  2.4.4
# aiohttp                           3.11.10
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.16
# altair                            5.5.0
# anaconda-anon-usage               0.7.1
# anaconda-auth                     0.8.6
# anaconda-catalogs                 0.2.0
# anaconda-cli-base                 0.5.2
# anaconda-client                   1.13.0
# anaconda-navigator                2.6.6
# anaconda-project                  0.11.1
# annotated-types                   0.6.0
# anyio                             4.7.0
# appdirs                           1.4.4
# archspec                          0.2.3
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# ...

# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from 'C:\\Users\\User\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
# numpy 생성
arr = np.arange(100, 105)
arr
# Out:
# array([100, 101, 102, 103, 104])

# %%
import numpy as np

# %%
# numpy 생성
arr = np.arange(100, 105)
arr
# Out:
# array([100, 101, 102, 103, 104])

# %%
s = pd.Series(arr)
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int64

# %%
s = pd.Series(arr, dtype='int32')
s
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# dtype: int32

# %%
s = pd.Series(['부장', '차장', '대리', '사원', '인턴'])
s
# Out:
# 0    부장
# 1    차장
# 2    대리
# 3    사원
# 4    인턴
# dtype: object

# %%
s = pd.Series([91, 2.5, '스포츠', 4, 5.16])
s
# Out:
# 0      91
# 1     2.5
# 2     스포츠
# 3       4
# 4    5.16
# dtype: object

# %%
s = pd.Series(['부장', '차장', '대리', '사원', '인턴'])
s
# Out:
# 0    부장
# 1    차장
# 2    대리
# 3    사원
# 4    인턴
# dtype: object

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s[0]
# Out:
# '부장'

# %%
s[1:3]
# Out:
# 1    차장
# 2    대리
# dtype: object

# %%
s[np.arange(1, 4, 2)]
# Out:
# 1    차장
# 3    사원
# dtype: object

# %%
np.random.seed(0)
s = pd.Series(np.random.randint(10000, 20000, size=(10,)))
s
# Out:
# 0    12732
# 1    19845
# 2    13264
# 3    14859
# 4    19225
# 5    17891
# 6    14373
# 7    15874
# 8    16744
# 9    13468
# dtype: int32

# %%
rng = np.random.default_rng(42)
pd.Series(rng.integers(10000, 20000, 10))
# Out:
# 0    10892
# 1    17739
# 2    16545
# 3    14388
# 4    14330
# 5    18585
# 6    10859
# 7    16973
# 8    12014
# 9    10941
# dtype: int64

# %%
s > 15000
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7     True
# 8     True
# 9    False
# dtype: bool

# %%
s[s > 15000]
# Out:
# 1    19845
# 4    19225
# 5    17891
# 7    15874
# 8    16744
# dtype: int32

# %%
s = pd.Series(['마케팅', '경영', '개발', '기획', '인사'], index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    마케팅
# b     경영
# c     개발
# d     기획
# e     인사
# dtype: object

# %%
s['c']
# Out:
# '개발'

# %%
s[['a', 'd']]
# Out:
# a    마케팅
# d     기획
# dtype: object

# %%
s = pd.Series(['마케팅', '경영', '개발', '기획', '인사'])
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.index = list('abcde')

# %%
s
# Out:
# a    마케팅
# b     경영
# c     개발
# d     기획
# e     인사
# dtype: object

# %%
s = pd.Series(['선화', '강호', np.nan, '소정', '우영'])
s
# Out:
# 0     선화
# 1     강호
# 2    NaN
# 3     소정
# 4     우영
# dtype: object

# %%
s[s.isnull()]
# Out:
# 2    NaN
# dtype: object

# %%
s.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
s[s.isnull()]
# Out:
# 2    NaN
# dtype: object

# %%
s[s.notnull()]
# Out:
# 0    선화
# 1    강호
# 3    소정
# 4    우영
# dtype: object

# %%
s.notna()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
s[s.notna()]
# Out:
# 0    선화
# 1    강호
# 3    소정
# 4    우영
# dtype: object

# %%
s = pd.Series(np.arange(100, 150, 10))
s
# Out:
# 0    100
# 1    110
# 2    120
# 3    130
# 4    140
# dtype: int64

# %%
s.index = list('가나다라마')
s
# Out:
# 가    100
# 나    110
# 다    120
# 라    130
# 마    140
# dtype: int64

# %%
pd.Series(np.arange(1,11,1), dtype='float32')
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     4.0
# 4     5.0
# 5     6.0
# 6     7.0
# 7     8.0
# 8     9.0
# 9    10.0
# dtype: float32

# %%
s = pd.Series(['가', '나', '다', '라', '마'])
s
# Out:
# 0    가
# 1    나
# 2    다
# 3    라
# 4    마
# dtype: object

# %%
s.index = list('가나다라마')

# %%
s
# Out:
# 가    가
# 나    나
# 다    다
# 라    라
# 마    마
# dtype: object

# %%
s.arange((10,60,10), dtype="int64")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 s.arange((10,60,10), dtype="int64")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'arange'

# %%
s = np.arange(10, 60, 10)

# %%
s
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.Series
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 s.Series
#
# AttributeError: 'numpy.ndarray' object has no attribute 'Series'

# %%
s.Series()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 s.Series()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'Series'

# %%
S = pd.Series(s)

# %%
S
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
S.index = list('가나다라마')

# %%
S
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int64

# %%
pd.DataFrame([[1, 2, 3], 
              [4, 5, 6], 
              [7, 8, 9]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
pd.DataFrame([[1, 2, 3], 
              [4, 5, 6], 
              [7, 8, 9]], columns=['가', '나', '다'])
# Out:
#    가  나  다
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data = {
    'name': ['Kim', 'Lee', 'Park'], 
    'age': [24, 27, 34], 
    'children': [2, 1, 3]
}

# %%
pd.DataFrame(data)
# Out:
#    name  age  children
# 0   Kim   24         2
# 1   Lee   27         1
# 2  Park   34         3

# %%
df = pd.DataFrame(data)
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df = pd.DataFrame(data)
df.columns
# Out:
# Index(['name', 'age', 'children'], dtype='object')

# %%
df.values
# Out:
# array([['Kim', 24, 2],
#        ['Lee', 27, 1],
#        ['Park', 34, 3]], dtype=object)

# %%
df.dtypes
# Out:
# name        object
# age          int64
# children     int64
# dtype: object

# %%
df.T
# Out:
#             0    1     2
# name      Kim  Lee  Park
# age        24   27    34
# children    2    1     3

# %%
df
# Out:
#    name  age  children
# 0   Kim   24         2
# 1   Lee   27         1
# 2  Park   34         3

# %%
df.index = list('abc')
df
# Out:
#    name  age  children
# a   Kim   24         2
# b   Lee   27         1
# c  Park   34         3

# %%
df['name']
# Out:
# a     Kim
# b     Lee
# c    Park
# Name: name, dtype: object

# %%
type(df['name'])
# Out:
# pandas.core.series.Series

# %%
df[['name', 'age']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 df[['name', 'age']]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
pd.DataFrame([[k, 2, 3], 
              [4, 5, 6], 
              [7, 8, 9]], columns=['food', 'price', 'rating'])
# Out:
#    가  나  다
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
data = {
    'food': ['KFC', 'Mc', 'SF'], 
    'price': [1000, 2000, 2500], 
    'rating': [4.5, 3.9, 4.2]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   food  price  rating
# 0  KFC   1000     4.5
# 1   Mc   2000     3.9
# 2   SF   2500     4.2

# %%
df[['food', 'rating']]
# Out:
#   food  rating
# 0  KFC     4.5
# 1   Mc     3.9
# 2   SF     4.2

# %%
df= df.rename(columns={'food' : 'place'})
df
# Out:
#   place  price  rating
# 0   KFC   1000     4.5
# 1    Mc   2000     3.9
# 2    SF   2500     4.2

# %%
arr = np.arange(10,60,10)

# %%
sample = pd.Series(arr)

# %%
sample
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
sample = pd.Series(arr, index=list("가나다라마"))

# %%
sample
# Out:
# 가    10
# 나    20
# 다    30
# 라    40
# 마    50
# dtype: int64

# %%
sample[["나", "라"]]
# Out:
# 나    20
# 라    40
# dtype: int64

# %%
np.random.seed(20)
sample2 = pd.Series(np.random.randint(100, 200, size=(15,)))
sample2
# Out:
# 0     199
# 1     190
# 2     115
# 3     195
# 4     128
# 5     190
# 6     109
# 7     120
# 8     175
# 9     122
# 10    171
# 11    134
# 12    196
# 13    140
# 14    185
# dtype: int32

# %%
a = sample2[sample2 <= 160]

# %%
a
# Out:
# 2     115
# 4     128
# 6     109
# 7     120
# 9     122
# 11    134
# 13    140
# dtype: int32

# %%
b = sample2[129 < sample2 < 171]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 b = sample2[129 < sample2 < 171]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1580, in NDFrame.__nonzero__(self)
#    1578 @final
#    1579 def __nonzero__(self) -> NoReturn:
# -> 1580     raise ValueError(
#    1581         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
