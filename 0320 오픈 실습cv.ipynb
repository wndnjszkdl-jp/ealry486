# %%
import cv2
import numpy as np

# 세로 480 * 가로 640 , 3 채널 [RGB]에 해당하는 빈 스케치북 만들기

img = np.zeros((480,640,3), dtype=np.uint8)
COLOR = (0, 250, 0)
COLOR2 = (0, 0, 250)
THIC = 5
pt1 = np.array([[200,200], [400,200], [300,50]])
pt2 = np.array([[100,400],[150,250],  [200,330], [250,250], [300,400]])
# pt2 = np.array([[200,100], [300,100], [300,200]])

cv2.polylines( img, [pt1] , True, COLOR, THIC, cv2.LINE_AA)
# cv2.polylines( img, [pt2] , True, COLOR, THIC, cv2.LINE_AA)
cv2.fillPoly( img, [pt2] , COLOR2,  cv2.LINE_AA)


cv2.imshow('polylines',img)
cv2.waitKey(0)
cv2.destroyAllWindows
